# %% [markdown]
# <img src="../resources/HTLstp-RGB150.png" alt="HTL" width=200>
# REFR - Prof. Franz Reichel
#
# DSAI - 4XHIF Klasse
#
# ---

# %% [markdown]
# # 🐧 Seaborn – Einführung & Beispielplots

# %% [markdown]
# ## 📦 Importieren & Datensatz laden

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Beispiel-Datensatz
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 🔹 Scatterplot

# %%
sns.scatterplot(data=df, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.title('Pinguin-Schnabel: Länge vs. Tiefe')
plt.show()

# %% [markdown]
# ## 🔹 Histogramm mit Dichtekurve

# %%
sns.histplot(data=df, x='flipper_length_mm', hue='species', kde=True)
plt.title('Verteilung der Flossenlänge nach Art')
plt.show()

# %% [markdown]
# ## 🔹 Boxplot & Violinplot

# %%
sns.boxplot(data=df, x='species', y='body_mass_g')
plt.title('Körpergewicht nach Pinguinart (Boxplot)')
plt.show()

sns.violinplot(data=df, x='species', y='body_mass_g')
plt.title('Körpergewicht nach Pinguinart (Violinplot)')
plt.show()

# %% [markdown]
# ## 🔹 Pairplot – Beziehungen zwischen Variablen

# %%
sns.pairplot(df, hue='species')
plt.suptitle('Pinguin-Daten – Korrelationsübersicht', y=1.02)
plt.show()

# %% [markdown]
# ## 🔹 Heatmap der Korrelationen

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Korrelationsmatrix der numerischen Variablen')
plt.show()

# %% [markdown]
# ## 🎨 Bonus: Stil und Palette

# %%
sns.set_style('whitegrid')
sns.set_palette('pastel')

sns.boxplot(data=df, x='species', y='flipper_length_mm')
plt.title('Flossenlänge mit anderem Stil & Palette')
plt.show()
